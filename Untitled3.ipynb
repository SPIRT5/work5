# %% [markdown]
# <a href="https://colab.research.google.com/github/SPIRT5/work5/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Задание 1.
#
# Z-критерий используется, когда:
#
# 1. Известна стандартная ошибка (дисперсия) генеральной совокупности.
#
# 2. Размер выборки достаточно большой (обычно n > 30).
#
# Критерий Стьюдента используется, когда:
#
# 1. Стандартное отклонение генеральной совокупности неизвестно. Вместо этого используется стандартное отклонение выборки.
#
# 2. Размер выборки небольшой (обычно n ≤ 30).

# %% [markdown]
# Задание 2.
#
# В данной задаче будем использовать Z-критерий.
#
# Z= (17,5-17)/(2/10) = 0,5/0,2 =2.5
#
# Для уровня значимости
# 𝛼
# =
# 0.05
# α=0.05 и одностороннего теста, критическое значение Z находится из стандартной нормальной таблицы распределения:
#
# Z critical=1.645
#
# Поскольку вычисленное Z-значение (2.5) больше критического значения (1.645), мы отвергаем нулевую гипотезу.
#
# На уровне значимости α=0.05 у нас есть достаточные основания отклонить нулевую гипотезу. Это означает, что существует статистически значимое доказательство того, что средний диаметр шариков, изготовленных автоматическим станком, превышает 17 мм.

# %% [markdown]
# Задание 3.
#
# Выборочное среднее
# X= 10/(202+203+199+197+195+201+200+204+194+190)= 10/1985=198.5
#
# Выборочное стандартное отклонение
# 𝑠=(∑(𝑥𝑖−𝑋‾)2)/𝑛−1
#
# Посчитаем отклонения, их квадраты и сумму квадратов отклонений:
#
# (202−198.5)2=12.25
#
# (203−198.5)2=20.25
#
# (199−198.5)2=0.25
#
# (197−198.5)2=2.25
#
# (195−198.5)2=12.25
#
# (201−198.5)2=6.25
#
# (200−198.5)2=2.25
#
# (204−198.5)2=30.25
#
# (194−198.5)2=20.25
#
# (190−198.5)2=72.25
#
# Сумма квадратов отклонений:
#
# ∑(x i− X) 2=178.75
#
# Теперь вычислим стандартное отклонение:
#
# 𝑠= корень 178.75 /(10−1)=корень19.861≈4.46
#
# Подставим известные значения в формулу:
#
# 𝑡=(198.5−200)/4.46/корень10=−1.5/1.411≈−1.06
#
#
# Для уровня значимости 𝛼=0.01 и двустороннего теста с 𝑑𝑓=𝑛−1=9, критическое значение t можно найти в таблице критических значений t-распределения:
#
# tcritica=±3.249 (для 𝛼/2=0.005 и df = 9
#
# Поскольку вычисленное t-значение (-1.06) находится в пределах критических значений (-3.249 и 3.249), мы не отвергаем нулевую гипотезу.
#
# На уровне значимости α=0.01 у нас нет достаточных оснований отвергнуть нулевую гипотезу. Это означает, что утверждение продавца о том, что средний вес пачки печенья составляет 200 г, верно в пределах 99% доверительной вероятности.

# %% [markdown]
# Задание 4.
#
# Разности между парами наблюдений
#
#  Разности=[172−173,177−175,158−162,170−174,178−175,175−168,164−155,160−170,169−160]
#
# Разности=[−1,2,−4,−4,3,7,9,−10,9]
#
# Средняя разность:
#
# (−1+2−4−4+3+7+9−10+9)/9= 9/11≈1.22
#
# Сумма квадратов отклонений разностей от среднего:
#
# (−1−1.22)2= 4.84
#
# (2−1.22)2= 0.6084
#
# (−4−1.22)2= 27.6484
#
# (−4−1.22)2= 27.6484
#
# (3−1.22)2= 3.1684
#
# (7−1.22)2= 33.5484
#
# (9−1.22)2= 60.3484
#
# (−10−1.22)2= 125.7284
#
# (9−1.22)2= 60.3484
#
#  Сумма квадратов отклонений= 344.896
#
#  Стандартное отклонение разностей:
#
#  s d= корень((9−1)/ 344.896)= корень 43.112≈6.56
#
# Вычисление t-статистики
#
#  (6.56/корень9)/ 1.22= (6.56/3) /1.22= 2.19 /1.22≈0.56
#
#  Для уровня значимости α=0.05 (двусторонний тест) и степеней свободы df=n−1=8:
#
# Критическое значение t из таблицы критических значений t-распределения:
#
# tcritical=±2.306 (для α/2=0.025 и df=8)
#
# Поскольку вычисленное значение t (0.56) меньше критического значения t (2.306), мы не отвергаем нулевую гипотезу.
#
# На уровне значимости α=0.05 у нас нет достаточных оснований утверждать, что есть статистически значимые различия в росте матерей и их взрослых дочерей.
